# %% [markdown]
# # Data Cleaning and Visualization using Python
#
#
# ## Objective
# To clean the Titanic dataset by handling missing values, removing duplicates, and performing Exploratory Data Analysis (EDA) using Python libraries such as Pandas, NumPy, Matplotlib, and Seaborn.
#
# ## Import libraries
#
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# ## Load dataset
#
# df = sns.load_dataset('titanic')
#
# ## Display first 5 rows
#
# print(df.head())
#
# ### Observation
#
# The dataset contains passenger information such as age, fare, passenger class, and survival status.
#
# ## check dataset information
#
# print(df.info())
#
# ## Check Missing Values
#
# print(df.isnull().sum())
# df = df.drop_duplicates()
# print(df.isnull().sum())
#
#
# ### Observation
# The dataset contains missing values in the Age and Embarked columns.
#
#
# ## Fill Missing Values
#
# df['age'] = df['age'].fillna(df['age'].median())
# df['embarked'] = df['embarked'].fillna(df['embarked'].mode()[0])
#
#
# ## Check Missing Values Again
#
# print(df.isnull().sum())
#
# ### Summary Statistics
#
# print(df.describe())
#
# # Create Histogram
#
# plt.figure(figsize=(6,4))
# plt.hist(df['age'], bins=20)
# plt.title("Age Distribution")
# plt.xlabel("Age")
# plt.ylabel("Count")
# plt.show()
#
# ### Observation
# Most passengers are between 20 and 40 years old.
#
#
# # Create Bar Chart
#
# plt.figure(figsize=(6,4))
# sns.countplot(x='survived', data=df)
# plt.title("Survival Count")
# plt.show()
#
# ### Observation
# More passengers did not survive than survived.
#
# # Create Box Plot
#
# plt.figure(figsize=(6,4))
# sns.boxplot(x=df['fare'])
# plt.title("Fare Box Plot")
# plt.show()
#
# ### Observation
# The Fare column contains several outliers.
#
# # Create Correlation Heatmap
#
# plt.figure(figsize=(8,6))
# sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
# plt.title("Correlation Heatmap")
# plt.show()
#
# ### Observation
# The heatmap shows the correlation between numerical features.
#
# ## Conclusion
#
# The Titanic dataset was successfully cleaned and analyzed using Python. Missing values were handled, duplicate records were removed, and visualizations such as histograms, bar charts, box plots, and a correlation heatmap were created. This analysis helped identify patterns, trends, and relationships within the dataset.

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load Dataset
df = sns.load_dataset('titanic')

# Display First 5 Rows
print(df.head())

# Check Dataset Information
print(df.info())

# Check Missing Values
print(df.isnull().sum())

# Remove Duplicate Rows
df = df.drop_duplicates()

# Fill Missing Values
df['age'] = df['age'].fillna(df['age'].median())
df['embarked'] = df['embarked'].fillna(df['embarked'].mode()[0])

# Check Missing Values Again
print(df.isnull().sum())

# Summary Statistics
print(df.describe())

# Histogram
plt.figure(figsize=(6,4))
plt.hist(df['age'], bins=20)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# Bar Chart
plt.figure(figsize=(6,4))
sns.countplot(x='survived', data=df)
plt.title("Survival Count")
plt.show()

# Box Plot
plt.figure(figsize=(6,4))
sns.boxplot(x=df['fare'])
plt.title("Fare Box Plot")
plt.show()

# Correlation Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...
